# %%
# Reference: https://github.com/seyedsaeidmasoumzadeh/Predict-next-word/blob/master/main.py

# %%
import collections
import tensorflow as tf
import numpy as np
from tensorflow.contrib import rnn
import nltk

# %%
#nltk.download('all')

# %%
# Word embedding
def word_embedding(words):
    vocabulary = collections.Counter(words).most_common()
    vocabulary_dictionary = dict()
    for word, _ in vocabulary:
        # Assign a numerical unique value to each word inside vocabulary 
        vocabulary_dictionary[word] = len(vocabulary_dictionary)
    rev_vocabulary_dictionary = dict(zip(vocabulary_dictionary.values(), vocabulary_dictionary.keys()))
    return vocabulary_dictionary, rev_vocabulary_dictionary

# %%
# Build Training data. For example if X = ['long', 'ago', ','] then Y = ['the']
def sampling(words, vocabulary_dictionary, window):
    X = []
    Y = []
    sample = []
    for index in range(0, len(words) - window):
        for i in range(0, window):
            sample.append(vocabulary_dictionary[words[index + i]])
            if (i + 1) % window == 0:
                X.append(sample)
                Y.append(vocabulary_dictionary[words[index + i + 1]])
                sample = []
    return X,Y

# %%
#Load text data

with open("train.txt") as f:
    content = f.read()
    
words = nltk.tokenize.word_tokenize(content)
vocabulary_dictionary, reverse_vocabulary_dictionary = word_embedding(words)

window = 3
num_classes = len(vocabulary_dictionary)
timesteps = window
num_hidden = 512
num_input = 1
batch_size = 20
iteration = 200


training_data, label = sampling(words, vocabulary_dictionary, window)

# %%
# RNN output node weights and biases
weights = {
    'out': tf.Variable(tf.random_normal([num_hidden, num_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# %%
# tf graph input
X = tf.placeholder("float", [None, timesteps, num_input])
Y = tf.placeholder("float", [None, num_classes])

# %%
def RNN(x, weights, biases):

    # Unstack to get a list of 'timesteps' tensors, each tensor has shape (batch_size, n_input)
    x = tf.unstack(x, timesteps, 1)

    # Build a LSTM cell
    lstm_cell = rnn.BasicLSTMCell(num_hidden, forget_bias=1.0)

    # Get LSTM cell output
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

# %%
logits = RNN(X, weights, biases)
prediction = tf.nn.softmax(logits)

# %%
# Loss and optimizer
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y))
train_op = tf.train.RMSPropOptimizer(learning_rate=0.001).minimize(loss_op)
correct_pred = tf.equal(tf.argmax(prediction,1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
# Initialize the variables with default values
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    # Run the initializer
    sess.run(init)
    for i in range(iteration):
        last_batch = len(training_data) % batch_size
        training_steps = int((len(training_data) / batch_size) + 1)
        for step in range(training_steps):
            X_batch = training_data[(step * batch_size) :((step + 1) * batch_size)]
            Y_batch = label[(step * batch_size) :((step + 1) * batch_size)]
            Y_batch_encoded = []
            for x in Y_batch:
                on_hot_vector = np.zeros([num_classes], dtype=float)
                on_hot_vector[x] = 1.0
                Y_batch_encoded = np.concatenate((Y_batch_encoded,on_hot_vector))
            if len(X_batch) < batch_size:
                X_batch = np.array(X_batch)
                X_batch = X_batch.reshape(last_batch, timesteps, num_input)
                Y_batch_encoded = np.array(Y_batch_encoded)
                Y_batch_encoded = Y_batch_encoded.reshape(last_batch, num_classes)
            else:
                X_batch = np.array(X_batch)
                X_batch = X_batch.reshape(batch_size, timesteps, num_input)
                Y_batch_encoded = np.array(Y_batch_encoded)
                Y_batch_encoded = Y_batch_encoded.reshape(batch_size, num_classes)
            _, acc, loss, onehot_pred = sess.run([train_op, accuracy, loss_op, logits], feed_dict={X: X_batch, Y: Y_batch_encoded})
            print("Step " + str(i) + ", Minibatch Loss= " + "{:.4f}".format(loss) + ", Training Accuracy= " + "{:.2f}".format(acc * 100))
# Out:
# Step 0, Minibatch Loss= 41.3661, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 37.4009, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 38.8068, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 41.3389, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 40.3996, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 43.0225, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 34.1131, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 33.8994, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 35.4247, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 29.2236, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 28.1835, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 26.4462, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 28.3528, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 30.8743, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 30.2847, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 27.5918, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 23.5280, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 28.2995, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 21.5610, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 25.5832, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 26.0366, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 23.7716, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 23.9877, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 22.1952, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 26.1506, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 22.0738, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 20.7591, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 27.2582, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 27.6477, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 22.8831, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 25.2279, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 22.1093, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 28.0185, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 26.2889, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 21.8571, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 22.8348, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 18.1460, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 25.3838, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 23.8455, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 19.8123, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 17.5321, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 18.1992, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 17.6361, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 17.0546, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 20.6756, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 15.9110, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 20.1917, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 18.3323, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 18.9907, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 21.8976, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 16.7206, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 18.4323, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 18.4373, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 16.4498, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 19.4092, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 16.1789, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 16.4812, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 17.1914, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 18.3544, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 17.9132, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 16.4588, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 16.1703, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.5278, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 17.2463, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 15.5327, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 17.9512, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 16.1307, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.8003, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.9395, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 15.3436, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.8091, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 15.4813, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 15.5901, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 15.7962, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 16.4499, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 17.0483, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 15.8995, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 17.0386, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.8026, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.3466, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 16.8390, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 15.0632, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.3570, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 15.6238, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 14.0570, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.8846, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.6671, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 15.9976, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 15.8251, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.6853, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.8984, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.7584, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 14.6290, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.8593, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 15.6888, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.2847, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 15.0839, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.4725, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.7824, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.9323, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.7519, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 14.3334, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.7990, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.1188, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.7130, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.3763, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.4138, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.5961, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 14.7592, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.4257, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 13.0805, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 13.1087, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.5699, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 13.3851, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.5916, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.1050, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.0772, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 13.4017, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.1333, Training Accuracy= 20.00
# Step 0, Minibatch Loss= 13.5459, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.7513, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.4473, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.8854, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.0176, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.0221, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.1484, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 14.9433, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.3062, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.8712, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.8587, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.6578, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.2325, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.2998, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 15.9319, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.7008, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.7090, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.6526, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.2250, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 14.3505, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.9052, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.6425, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.0151, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.5980, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.3891, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.4016, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.0187, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 14.9105, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.4272, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.4794, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.7518, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.6831, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.9753, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.5230, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.5248, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 15.0145, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 14.1835, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.0893, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.5815, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.9862, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.2237, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.1807, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.5430, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.3340, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.8907, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.7919, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.8692, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9380, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 12.8069, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.8299, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.5312, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.3717, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.7954, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.0999, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.8326, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.9338, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.8477, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.0784, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.1510, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.4893, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.1838, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.7780, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.1422, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.2229, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.0012, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.6828, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.6419, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.8600, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.5442, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.8422, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 14.6595, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.2299, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.0335, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 14.0644, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.0760, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.6759, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.0895, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 14.3386, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.0309, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.5860, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.4786, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.8287, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.1636, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.4047, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.1569, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.1433, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.5335, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.3009, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.2715, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.8602, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.7058, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.2169, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.5588, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.6501, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.7543, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9717, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.6698, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.5658, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.0535, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.8867, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.4373, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 13.0198, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.1667, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.5202, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.5834, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 12.2035, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 13.5239, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.8585, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.4873, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.6879, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.1860, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.3639, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.8078, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.3024, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.3789, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.5402, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.2010, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.8351, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.1476, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.3701, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 12.5080, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.9090, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.2643, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.5911, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.5666, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.4469, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.7472, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.2075, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 12.8632, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.8329, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.1329, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.7607, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.3503, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.3689, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.4540, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.0323, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.4132, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.1155, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.7669, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.6827, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.9011, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.3155, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.1571, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.5509, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.3689, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.3722, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.6503, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.6683, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.4944, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.4115, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.6718, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.8981, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.7757, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.9638, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 14.6373, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.5183, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9792, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.3774, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 12.0479, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.1690, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.4336, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.1382, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.8597, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.8311, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.3954, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.4841, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.0028, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.5060, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.7259, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.0617, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.7825, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.0713, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.0475, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.4501, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.6998, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.4804, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.6493, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.4992, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.1552, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9798, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.2130, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.1982, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.5193, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.3501, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.9886, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.6905, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.9326, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.8415, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.5917, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.2936, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9940, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.0640, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.1960, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.9933, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.2344, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.1049, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.4059, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.7403, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1733, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.8527, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.0704, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.3577, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.2418, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.5361, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.9766, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.3802, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.8579, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.3955, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.3853, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.7244, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.6061, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 15.1752, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.3701, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.8220, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.6972, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.6619, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 13.9702, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.2728, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.8058, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.2149, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.0104, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.9090, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.3947, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.2772, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.2780, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.8201, Training Accuracy= 20.00
# Step 0, Minibatch Loss= 10.8040, Training Accuracy= 30.00
# Step 0, Minibatch Loss= 12.6445, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.8330, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9526, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.4115, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.6879, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.8818, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.1188, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.9747, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.4025, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.5658, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.7442, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.9940, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.6562, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4291, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.7436, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.2544, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.5062, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 14.3535, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.9834, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.9591, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 10.3569, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.8745, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.9743, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.0874, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.9216, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.6626, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.9106, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.5428, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.1801, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.1181, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.4393, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.1294, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.3337, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4084, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.3568, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 8.7857, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.2627, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.6902, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.4188, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.4374, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 9.7697, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.6660, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1697, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 14.9080, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.6123, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.0459, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.8852, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9914, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.1353, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.8572, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.5961, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.8900, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.7921, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9908, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.7524, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.1280, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 10.8190, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.7369, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4590, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.3362, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.0593, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.5735, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.6983, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.1662, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.3939, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.2340, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.2234, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.7131, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4147, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4657, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.9644, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.0625, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.1132, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.4131, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.1202, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.8280, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.2411, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.5486, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.3844, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.3972, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.2205, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 10.3288, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.4006, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.7107, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.3884, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.6758, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.6784, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.8416, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4630, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.7488, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.4498, Training Accuracy= 20.00
# Step 0, Minibatch Loss= 10.7889, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.9509, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.5291, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.1196, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.6060, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.3224, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.4777, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.9107, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.4654, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.1039, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 14.1092, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.2144, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.7012, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.0356, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.1120, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.4649, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.8153, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.5189, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.7748, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 13.8799, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.3661, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.4150, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.4843, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.3036, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.3446, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.4804, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 12.4038, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.8798, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.9326, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.9800, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.5006, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.9303, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 13.0770, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.3937, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.5586, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.7316, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 14.0560, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.0854, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.1675, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4379, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.9909, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.2325, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.1999, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.2657, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.4495, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.9876, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.9853, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 12.5898, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4680, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.3880, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.5590, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 12.3666, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.7766, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.5837, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.1554, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.0137, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.7862, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.7306, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.6565, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.3152, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.4606, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.3647, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 13.0139, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.0721, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.7185, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.2440, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.5684, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 13.1484, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.8497, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.0768, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.3531, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.1313, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.8525, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.8583, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.2694, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.3816, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.8672, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.6880, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.3016, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.5061, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.9774, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.8253, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.1066, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.3079, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.9806, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.3901, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.8256, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.6021, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.2310, Training Accuracy= 20.00
# Step 0, Minibatch Loss= 11.7088, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.6111, Training Accuracy= 20.00
# Step 0, Minibatch Loss= 12.6904, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.7084, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.3693, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.1477, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.1669, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.2215, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.2506, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.8066, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.0011, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.8123, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.5445, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.9079, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.3979, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.6238, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.4376, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.6368, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.6887, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.7321, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.7334, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.9761, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.0123, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.6695, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.7766, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.0734, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 7.7947, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.0347, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.3331, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.7297, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 8.5986, Training Accuracy= 20.00
# Step 0, Minibatch Loss= 11.8858, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.1039, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 8.6058, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.8985, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.0072, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.3870, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.2656, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.5402, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.0691, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.6564, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.9708, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.2288, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.5865, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.8668, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.6291, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.9721, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.6721, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.5911, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.0923, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.3681, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.2434, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9179, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.2030, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.2367, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.7321, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.0370, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 13.5627, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.8890, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.0231, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.1170, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.9350, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.1942, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.5355, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 9.4298, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.8823, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.6542, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1837, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.1497, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.4133, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9503, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.5100, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.0052, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9662, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9703, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.6402, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.2994, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.7540, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9565, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.4840, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.8747, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.2832, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.3431, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.5354, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.1371, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.6621, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.9539, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.1565, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.5204, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 9.4563, Training Accuracy= 20.00
# Step 0, Minibatch Loss= 10.8915, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.2251, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.1738, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.3661, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 10.5617, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.8179, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.3063, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.9524, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.6850, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.1039, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.3161, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.2132, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.8240, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.7158, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.1647, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.4952, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.9022, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.4882, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.3185, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.7544, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.8895, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.8420, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.7229, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4338, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1013, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 12.5800, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.9508, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.8633, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.1266, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.7198, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.7166, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.3795, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.3522, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.2097, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.5395, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.8099, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.5517, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.2296, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.0662, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.3473, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.1072, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.8746, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.6859, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.2917, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 9.7224, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.7445, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 7.8087, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.6646, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.2685, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.9835, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.9464, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.2966, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.5124, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 9.6277, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.2395, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 9.1077, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.0628, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 8.3952, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.9519, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.7310, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.6265, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.8051, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.5017, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1461, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.6202, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.7947, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.2917, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.5503, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.8531, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.8733, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.0666, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.4746, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 13.6190, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.5909, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 13.9607, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4526, Training Accuracy= 20.00
# Step 0, Minibatch Loss= 13.7411, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.0646, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.5667, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.7105, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.7020, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.1766, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.9775, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.3572, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1818, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.6537, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.0569, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.5751, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4657, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.1942, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.1573, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.8499, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.9109, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1340, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.1763, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.5230, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.1147, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.9272, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 9.4796, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.5837, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 8.3912, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 8.7300, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.1361, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1132, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.4279, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.3179, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1125, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.8040, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.1504, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.3141, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 8.2091, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.6945, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 7.0840, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.5119, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.5524, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.3944, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.4356, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.8088, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.2483, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.5153, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.6133, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.8224, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.0969, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.4635, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.1778, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.6067, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.7875, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.6066, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.7888, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.6749, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.5540, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.5594, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 7.3717, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.1928, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.0058, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.8073, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.9882, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.1903, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.4475, Training Accuracy= 20.00
# Step 0, Minibatch Loss= 10.6764, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.0972, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.4699, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.9197, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.7649, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.8438, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 9.0466, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.2735, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.9485, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 14.0563, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.8431, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.8146, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 7.7788, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 7.7135, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.6364, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.7124, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.3300, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 8.7643, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.6932, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.4719, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.8130, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.0859, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.3908, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.1540, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.2299, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.5635, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.8267, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 7.7243, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.2303, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.1644, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.8523, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.1022, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1693, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.9936, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 9.6386, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.0539, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.9283, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.2596, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.8864, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.1152, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.0754, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.0727, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.6206, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.3367, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.0266, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.7102, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.8044, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.0392, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.8200, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.0582, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.0530, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.9736, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.5484, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.1220, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.7514, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.3773, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.6150, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.3019, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 10.9607, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.6753, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.0756, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 8.8426, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.9521, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.9296, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 8.8904, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 7.8991, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.0941, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.6970, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.2998, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.2371, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.0478, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.3793, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.5906, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.5567, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.0226, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.7932, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.5301, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.6688, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.1659, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.4633, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.6991, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.5366, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.2665, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.2384, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.9422, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.6887, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.8799, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.8568, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.1383, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.0691, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4195, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.8747, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.3040, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.1800, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.9531, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.4035, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.6125, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.8372, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.0552, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 10.5748, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.5494, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.5675, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.3608, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 10.8091, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.5451, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.5433, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 10.7330, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.5211, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 9.8228, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.5499, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.5650, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.7150, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.4929, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.0024, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.4435, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.1304, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.7587, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.8607, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.4395, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.3839, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.9022, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.7030, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.1824, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 8.9806, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 8.1876, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.5257, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.2803, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.3660, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.1963, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.1456, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.9695, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 7.4836, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.1603, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 8.4845, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.6975, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.3089, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 10.6312, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.8157, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.3347, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.9770, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.4533, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.1351, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.4206, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 10.6065, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.7193, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.4041, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.2261, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.0091, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.5180, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.3185, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.5066, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.7159, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1156, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1331, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.8593, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.0217, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.6076, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.3644, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.7258, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.1821, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.4962, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.4145, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.3074, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.7251, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.3334, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 12.9756, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.1377, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.7487, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.1910, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.0915, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.7868, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.4616, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.1987, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.5186, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.5126, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.7634, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 8.3563, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.8182, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.2124, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.2641, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.5550, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.5773, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.4972, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.9209, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.9503, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.7335, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.4479, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 13.0832, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 9.3128, Training Accuracy= 20.00
# Step 0, Minibatch Loss= 9.0397, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.2327, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 10.3014, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.4138, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.2906, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.3021, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.7146, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 12.1896, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.3725, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.4475, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1316, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.4977, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.7997, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1317, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.9163, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.0222, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.9330, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.0110, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.5165, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.4452, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.8547, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.3489, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.7505, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.2115, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.5167, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.0053, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.2987, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.2897, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.4698, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.8614, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.7587, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.8283, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.7145, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.8261, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 8.3282, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 9.8373, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.3337, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.6289, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.7853, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.5286, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 8.7125, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.1565, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 13.2743, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.5377, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.5791, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.0116, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.5019, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 10.0397, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.3621, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 8.0586, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.1254, Training Accuracy= 20.00
# Step 0, Minibatch Loss= 14.0992, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 7.7594, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.5847, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.0970, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.8747, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 11.1003, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.0097, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.1838, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.9711, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.9955, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 7.5616, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 11.8167, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 11.1159, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 10.2903, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.3430, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 11.0302, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.0695, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.3952, Training Accuracy= 15.00
# Step 0, Minibatch Loss= 8.8092, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 9.0083, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 10.5713, Training Accuracy= 0.00
# Step 0, Minibatch Loss= 7.8341, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.1521, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 9.6785, Training Accuracy= 5.00
# Step 0, Minibatch Loss= 10.0259, Training Accuracy= 10.00
# Step 0, Minibatch Loss= 12.5257, Training Accuracy= 0.00
